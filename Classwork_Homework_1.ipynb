# %% [markdown]
# <a href="https://colab.research.google.com/github/amandarice97/data-analytics/blob/main/Classwork_Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Classwork #1, Question #1**

# %%
(2**5)/(7*(4-2**3))
# Out:
# -1.1428571428571428

# %% [markdown]
# **Classwork #1, Question #2**
#
# 20 == '20'
#
# x = 4.0
# y = .5
#
# x < y or 3*y < x

# %%
20=="20"
# Out:
# False

# %%
x = 4.0
y = .5
x < y or 3*y < x
# Out:
# True

# %% [markdown]
# **Classwork #1, Question #3**
#
# fare = "$10.00"
# tip = "2.00$"
# tax = "$ 0.80"
#
# Write a Python code that uses slicing and the print() function to print out the following message:
#
# The total trip cost is: $12.80

# %%
fare = float ("10.00")
fare
# Out:
# 10.0

# %%
fare = "$10.00"
fare = fare [1:]
fare = float (fare)
fare
# Out:
# 10.0

# %%
tip = "2.00$"
tip = tip [-5:-2]
tip = float (tip)
tip
# Out:
# 2.0

# %%
tax = "$0.80"
tax = float (tax [2:])
tax
# Out:
# 0.8

# %%
total = fare + tip + tax
total
# Out:
# 12.8

# %%
print("The total trip cost is $", total)
# Out:
# The total trip cost is $ 12.8

# %% [markdown]
# **Classwork #1, Question #4**
#
# list_variable = [100, 144, 169, 1000, 8]
#
# Write a Python code that uses print() and max() functions to print out the largest value in the list, list_variable, as follows:
#
# The largest value in the list is: 1000

# %%
list_variable = [100, 144, 169, 1000, 8]
max(list_variable)
# Out:
# 1000

# %%
print("The largest value in the list is:", max(list_variable))
# Out:
# The largest value in the list is: 1000

# %% [markdown]
# **Classwork #1, Question #5**
#
# Import the pandas library as pd

# %%
import pandas

# %%
beer = pandas.read_csv("http://bcdanl.github.io/data/beer_markets.csv")
beer
# Out:
#             hh        _purchase_desc  quantity          brand  dollar_spent  \
# 0      2000946      BUD LT BR CN 12P         1      BUD LIGHT          8.14
# 1      2003036      BUD LT BR CN 24P         1      BUD LIGHT         17.48
# 2      2003036      BUD LT BR CN 24P         2      BUD LIGHT         33.92
# 3      2003036      BUD LT BR CN 30P         2      BUD LIGHT         34.74
# 4      2003036      BUD LT BR CN 36P         2      BUD LIGHT         40.48
# ...        ...                   ...       ...            ...           ...
# 73110  9158319  NATURAL LT BR CN 24P         1  NATURAL LIGHT         11.49
# 73111  9158319  NATURAL LT BR CN 24P         1  NATURAL LIGHT          9.97
# 73112  9158319  NATURAL LT BR CN 24P         1  NATURAL LIGHT          9.98
# 73113  9164033  NATURAL LT BR CN 30P         1  NATURAL LIGHT         12.98
# 73114  9164155  NATURAL LT BR CN 24P         1  NATURAL LIGHT         13.49
#
# ...

# %%
type(beer)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd

# %%
beer = pd.read_csv("http://bcdanl.github.io/data/beer_markets.csv")
beer
# Out:
#             hh        _purchase_desc  quantity          brand  dollar_spent  \
# 0      2000946      BUD LT BR CN 12P         1      BUD LIGHT          8.14
# 1      2003036      BUD LT BR CN 24P         1      BUD LIGHT         17.48
# 2      2003036      BUD LT BR CN 24P         2      BUD LIGHT         33.92
# 3      2003036      BUD LT BR CN 30P         2      BUD LIGHT         34.74
# 4      2003036      BUD LT BR CN 36P         2      BUD LIGHT         40.48
# ...        ...                   ...       ...            ...           ...
# 73110  9158319  NATURAL LT BR CN 24P         1  NATURAL LIGHT         11.49
# 73111  9158319  NATURAL LT BR CN 24P         1  NATURAL LIGHT          9.97
# 73112  9158319  NATURAL LT BR CN 24P         1  NATURAL LIGHT          9.98
# 73113  9164033  NATURAL LT BR CN 30P         1  NATURAL LIGHT         12.98
# 73114  9164155  NATURAL LT BR CN 24P         1  NATURAL LIGHT         13.49
#
# ...
