# %% [markdown]
# <a href="https://colab.research.google.com/github/amandarice97/data-analytics/blob/main/danl-m1-hw5-Rice-Amanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 5
# Dealing with Missing Values; Group Operations
#
# Import the pandas library, and read fao_stat.csv as fao:
#
# fao = pd.read_csv("https://bcdanl.github.io/data/fao_stat.csv",
#                   encoding = 'ISO-8859-1')

# %%
import pandas as pd
fao = pd.read_csv("https://bcdanl.github.io/data/fao_stat.csv",
                  encoding = 'ISO-8859-1')

# %% [markdown]
# # Variable Description
#
# The fao DataFrame contains the country-year level observation regarding variables below:
# - SSA: A boolean indicating if the country is in Sub-Saharan Africa.
# - Area: The name of the country.
# - Year: The year of observation.
# - gdp_per_capita: GDP per capita.
# - drinking_water: The percentage of the population with access to safe drinking water.
# - sanitation_service: The percentage of the population with access to improved sanitation services.
# - children_stunted: The percentage of children under 5 years old who are stunted.
# - children_overweight: The percentage of children under 5 years old who are overweight.
# - investment_pct: The percentage of GDP invested in public health.

# %%
fao
# Out:
#         SSA         Area  Year  gdp_per_capita  drinking_water  \
# 0     False  Afghanistan  2012          2075.5            53.4
# 1     False  Afghanistan  2013          2116.5            56.0
# 2     False  Afghanistan  2014          2102.4            58.7
# 3     False  Afghanistan  2015          2068.3            61.3
# 4     False  Afghanistan  2016          2057.1            64.1
# ...     ...          ...   ...             ...             ...
# 1849   True     Zimbabwe  2016          3678.2            64.5
# 1850   True     Zimbabwe  2017          3795.6            64.0
# 1851   True     Zimbabwe  2018          3923.0            63.5
# 1852   True     Zimbabwe  2019          3630.0            63.1
# 1853   True     Zimbabwe  2020          3353.4            62.7
#
#       sanitation_service  children_stunted  children_overweight  \
# 0                   38.0              44.7                  5.3
# 1                   39.5              43.4                  5.2
# ...

# %%
fao.info() # column names, count, data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1854 entries, 0 to 1853
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SSA                  1854 non-null   bool
#  1   Area                 1854 non-null   object
#  2   Year                 1854 non-null   int64
#  3   gdp_per_capita       1698 non-null   float64
#  4   drinking_water       1780 non-null   float64
#  5   sanitation_service   1772 non-null   float64
#  6   children_stunted     1404 non-null   float64
#  7   children_overweight  1404 non-null   float64
#  8   investment_pct       1791 non-null   float64
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 117.8+ KB

# %%
fao.nunique() # num. of unique values per variable
# Out:
# SSA                       2
# Area                    206
# Year                      9
# gdp_per_capita         1693
# drinking_water          430
# sanitation_service      604
# children_stunted        443
# children_overweight     181
# investment_pct         1791
# dtype: int64

# %% [markdown]
# # Question 1
#
# What percentage of the values is missing for each variable?
#
# *Answer*

# %%
fao.info() # column names, count, data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1854 entries, 0 to 1853
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SSA                  1854 non-null   bool
#  1   Area                 1854 non-null   object
#  2   Year                 1854 non-null   int64
#  3   gdp_per_capita       1698 non-null   float64
#  4   drinking_water       1780 non-null   float64
#  5   sanitation_service   1772 non-null   float64
#  6   children_stunted     1404 non-null   float64
#  7   children_overweight  1404 non-null   float64
#  8   investment_pct       1791 non-null   float64
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 117.8+ KB

# %%
(1-(1698/1854))*100 # 8.41% missing gdp_per_capita
# Out:
# 8.414239482200648

# %%
(1-(1780/1854))*100 # 3.99% missing drinking_water
# Out:
# 3.991370010787487

# %%
(1-(1772/1854))*100 # 4.42% missing sanitation_service
# Out:
# 4.42286947141316

# %%
(1-(1404/1854))*100 # 24.27% missing children_stunted & children_overweight
# Out:
# 24.271844660194176

# %%
(1-(1791/1854))*100 # 3.40% missing investment_pct
# Out:
# 3.398058252427183

# %% [markdown]
# # Question 2
# Fill missing values in the gdp_per_capita variable with the mean value of that variable.
#
# *Answer*

# %%
fao['gdp_per_capita'].mean()
# Out:
# 20344.85376914016

# %%
gdp_per_capita_mean = fao['gdp_per_capita'].mean()
fao['gdp_per_capita'] = fao['gdp_per_capita'].fillna(gdp_per_capita_mean) # fill missing values in the gdp_per_capita w/the mean value of that variable

# %%
fao['gdp_per_capita'].fillna(gdp_per_capita_mean).mean()
# Out:
# 20344.85376914016

# %%
fao.info() # count inc. from 1698 to 1854
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1854 entries, 0 to 1853
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SSA                  1854 non-null   bool
#  1   Area                 1854 non-null   object
#  2   Year                 1854 non-null   int64
#  3   gdp_per_capita       1854 non-null   float64
#  4   drinking_water       1780 non-null   float64
#  5   sanitation_service   1772 non-null   float64
#  6   children_stunted     1404 non-null   float64
#  7   children_overweight  1404 non-null   float64
#  8   investment_pct       1791 non-null   float64
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 117.8+ KB

# %% [markdown]
# # Question 3
# Drop observations where drinking_water or sanitation_service information is missing.
#
# *Answer*

# %%
fao.dropna(subset = ["drinking_water", "sanitation_service"]) # drop observations where drinking_water or sanitation_service info is missing
# Out:
#         SSA         Area  Year  gdp_per_capita  drinking_water  \
# 0     False  Afghanistan  2012          2075.5            53.4
# 1     False  Afghanistan  2013          2116.5            56.0
# 2     False  Afghanistan  2014          2102.4            58.7
# 3     False  Afghanistan  2015          2068.3            61.3
# 4     False  Afghanistan  2016          2057.1            64.1
# ...     ...          ...   ...             ...             ...
# 1849   True     Zimbabwe  2016          3678.2            64.5
# 1850   True     Zimbabwe  2017          3795.6            64.0
# 1851   True     Zimbabwe  2018          3923.0            63.5
# 1852   True     Zimbabwe  2019          3630.0            63.1
# 1853   True     Zimbabwe  2020          3353.4            62.7
#
#       sanitation_service  children_stunted  children_overweight  \
# 0                   38.0              44.7                  5.3
# 1                   39.5              43.4                  5.2
# ...

# %%
fao.dropna(subset = ["drinking_water", "sanitation_service"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1762 entries, 0 to 1853
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SSA                  1762 non-null   bool
#  1   Area                 1762 non-null   object
#  2   Year                 1762 non-null   int64
#  3   gdp_per_capita       1762 non-null   float64
#  4   drinking_water       1762 non-null   float64
#  5   sanitation_service   1762 non-null   float64
#  6   children_stunted     1364 non-null   float64
#  7   children_overweight  1364 non-null   float64
#  8   investment_pct       1717 non-null   float64
# dtypes: bool(1), float64(6), int64(1), object(1)
# memory usage: 125.6+ KB

# %% [markdown]
# # Question 4
# What is the average drinking_water access percentage for each Area grouped by SSA status?
#
# Hint: We can group a DataFrame by a list of multiple variables. Then, each group corresponds to a unique combination of values across the specified variables.
#
# (
#   fao
#   .groupby(['VARIABLE_1', 'VARIABLE_2'])
# )
#
# *Answer*

# %%
(
    fao
    .groupby("SSA")[['drinking_water']] # group by SSA
    .mean() # average drinking_water percentage
)
# Out:
#        drinking_water
# SSA
# False       93.681113
# True        65.686715

# %% [markdown]
# # Question 5
# Calculate the mean sanitation_service percentage for each combination of SSA status and Year.
#
# *Answer*

# %%
(
    fao
    .groupby("SSA")[['Year', 'sanitation_service']] # group by SSA
    .mean() # average sanitation_service
)
# Out:
#          Year  sanitation_service
# SSA
# False  2016.0           87.083456
# True   2016.0           36.533495

# %% [markdown]
# # Question 6
# For each year, find the 5 worst countries in terms of drinking_water.
#
# Hint: It would be a good idea to start with the DataFrame.sort_values() method.
# Note: DataFrameGroupBy does not support the sort_values() method. That is, DataFrameGroupBy.sort_values() will result in an error.
#
# *Answer*

# %%
fao['Year'].value_counts() # count by year
# Out:
# 2012    206
# 2013    206
# 2014    206
# 2015    206
# 2016    206
# 2017    206
# 2018    206
# 2019    206
# 2020    206
# Name: Year, dtype: int64

# %%
Year_2012 = fao["Year"] == 2012
fao[Year_2012].sort_values(["drinking_water"]).head(5) # worst 5, 2012
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 585    True                          Ethiopia  2012     1437.400000
# 1287  False                  Papua New Guinea  2012     3453.000000
# 477    True  Democratic Republic of the Congo  2012      926.800000
# 1548   True                       South Sudan  2012    20344.853769
# 1728   True                            Uganda  2012     1996.900000
#
#       drinking_water  sanitation_service  children_stunted  \
# 585             37.4                 6.6              42.8
# 1287            39.2                18.7              47.2
# 477             40.8                18.7              42.8
# 1548            41.2                 7.8              32.1
# 1728            43.2                18.7              34.1
#
#       children_overweight  investment_pct
# 585                   2.5       30.171755
# 1287                  8.1       29.342059
# 477                   4.6       25.982952
# ...

# %%
Year_2013 = fao["Year"] == 2013
fao[Year_2013].sort_values(["drinking_water"]).head(5) # worst 5, 2013
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 586    True                          Ethiopia  2013     1545.200000
# 1288  False                  Papua New Guinea  2013     3512.600000
# 1549   True                       South Sudan  2013    20344.853769
# 478    True  Democratic Republic of the Congo  2013      972.500000
# 316    True                              Chad  2013     1804.300000
#
#       drinking_water  sanitation_service  children_stunted  \
# 586             39.0                 6.9              41.8
# 1288            40.0                18.8              47.2
# 1549            41.3                 8.8              31.8
# 478             41.5                18.3              42.4
# 316             43.7                10.7              38.4
#
#       children_overweight  investment_pct
# 586                   2.4       30.750055
# 1288                  8.2       28.261088
# 1549                  6.2       28.091465
# ...

# %%
Year_2014 = fao["Year"] == 2014
fao[Year_2014].sort_values(["drinking_water"]).head(5) # worst 5, 2014
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 587    True                          Ethiopia  2014     1656.600000
# 1289  False                  Papua New Guinea  2014     3908.900000
# 1550   True                       South Sudan  2014    20344.853769
# 479    True  Democratic Republic of the Congo  2014     1029.800000
# 308    True          Central African Republic  2014      822.600000
#
#       drinking_water  sanitation_service  children_stunted  \
# 587             40.5                 7.2              41.0
# 1289            40.7                18.8              47.3
# 1550            41.3                 9.8              31.6
# 479             42.1                17.8              42.0
# 308             43.4                16.3              41.7
#
#       children_overweight  investment_pct
# 587                   2.4       34.980365
# 1289                  8.4       24.890038
# 1550                  6.0       21.597448
# ...

# %%
Year_2015 = fao["Year"] == 2015
fao[Year_2015].sort_values(["drinking_water"]).head(5) # worst 5, 2015
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 1551   True                       South Sudan  2015    20344.853769
# 1290  False                  Papua New Guinea  2015     4083.300000
# 588    True                          Ethiopia  2015     1779.100000
# 309    True          Central African Republic  2015      852.700000
# 480    True  Democratic Republic of the Congo  2015     1065.200000
#
#       drinking_water  sanitation_service  children_stunted  \
# 1551            41.2                10.9              31.4
# 1290            41.5                18.9              47.5
# 588             42.1                 7.5              40.1
# 309             42.3                16.0              41.7
# 480             42.7                17.4              41.7
#
#       children_overweight  investment_pct
# 1551                  5.9       19.993379
# 1290                  8.6        7.532394
# 588                   2.4       39.171956
# ...

# %%
Year_2016 = fao["Year"] == 2016
fao[Year_2016].sort_values(["drinking_water"]).head(5) # worst 5, 2016
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 1552   True                       South Sudan  2016    20344.853769
# 310    True          Central African Republic  2016      884.500000
# 1291  False                  Papua New Guinea  2016     4222.000000
# 481    True  Democratic Republic of the Congo  2016     1055.600000
# 589    True                          Ethiopia  2016     1894.900000
#
#       drinking_water  sanitation_service  children_stunted  \
# 1552            41.2                12.0              31.3
# 310             41.3                15.6              41.6
# 1291            42.3                18.9              47.6
# 481             43.4                17.0              41.7
# 589             43.6                 7.8              39.2
#
#       children_overweight  investment_pct
# 1552                  5.8       16.581448
# 310                   2.8       21.032317
# 1291                  8.7        7.392577
# ...

# %%
Year_2017 = fao["Year"] == 2017
fao[Year_2017].sort_values(["drinking_water"]).head(5) # worst 5, 2017
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 311    True          Central African Republic  2017      912.800000
# 1553   True                       South Sudan  2017    20344.853769
# 1292  False                  Papua New Guinea  2017     4285.100000
# 482    True  Democratic Republic of the Congo  2017     1059.800000
# 320    True                              Chad  2017     1587.000000
#
#       drinking_water  sanitation_service  children_stunted  \
# 311             40.2                15.2              41.4
# 1553            41.1                13.2              31.2
# 1292            43.0                19.0              47.9
# 482             44.0                16.6              41.6
# 320             45.1                11.4              36.4
#
#       children_overweight  investment_pct
# 311                   2.7       24.270628
# 1553                  5.7       18.963139
# 1292                  8.8        7.494033
# ...

# %%
Year_2018 = fao["Year"] == 2018
fao[Year_2018].sort_values(["drinking_water"]).head(5) # worst 5, 2018
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 312    True          Central African Republic  2018      933.100000
# 1554   True                       South Sudan  2018    20344.853769
# 1293  False                  Papua New Guinea  2018     4189.600000
# 483    True  Democratic Republic of the Congo  2018     1085.900000
# 321    True                              Chad  2018     1576.300000
#
#       drinking_water  sanitation_service  children_stunted  \
# 312             39.2                14.8              41.0
# 1554            41.0                14.5              31.0
# 1293            43.8                19.1              48.1
# 483             44.6                16.2              41.5
# 321             45.5                11.6              36.0
#
#       children_overweight  investment_pct
# 312                   2.7       24.436751
# 1554                  5.7       21.031039
# 1293                  8.9        7.636691
# ...

# %%
Year_2019 = fao["Year"] == 2019
fao[Year_2019].sort_values(["drinking_water"]).head(5) # worst 5, 2019
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 313    True          Central African Republic  2019      946.100000
# 1555   True                       South Sudan  2019    20344.853769
# 1294  False                  Papua New Guinea  2019     4292.600000
# 484    True  Democratic Republic of the Congo  2019     1097.900000
# 322    True                              Chad  2019     1579.600000
#
#       drinking_water  sanitation_service  children_stunted  \
# 313             38.2                14.5              40.5
# 1555            40.8                15.7              30.8
# 1294            44.6                19.1              48.3
# 484             45.3                15.8              41.2
# 322             45.8                11.8              35.5
#
#       children_overweight  investment_pct
# 313                   2.6       21.850431
# 1555                  5.7       18.459469
# 1294                  8.9        7.471472
# ...

# %%
Year_2020 = fao["Year"] == 2020
fao[Year_2020].sort_values(["drinking_water"]).head(5) # worst 5, 2020
# Out:
#         SSA                              Area  Year  gdp_per_capita  \
# 314    True          Central African Republic  2020      937.900000
# 1556   True                       South Sudan  2020    20344.853769
# 1295  False                  Papua New Guinea  2020     4063.200000
# 485    True  Democratic Republic of the Congo  2020     1082.400000
# 323    True                              Chad  2020     1509.000000
#
#       drinking_water  sanitation_service  children_stunted  \
# 314             37.2                14.1              40.1
# 1556            41.0                15.8              30.6
# 1295            45.3                19.2              48.4
# 485             46.0                15.4              40.8
# 323             46.2                12.1              35.0
#
#       children_overweight  investment_pct
# 314                   2.6       28.146001
# 1556                  5.7       19.747721
# 1295                  8.9        8.053913
# ...

# %% [markdown]
# # Question 7
# For each year, find the 5 worst countries in terms of children_stunted.
#
# *Answer*

# %%
fao['Year'].value_counts() # count by year
# Out:
# 2012    206
# 2013    206
# 2014    206
# 2015    206
# 2016    206
# 2017    206
# 2018    206
# 2019    206
# 2020    206
# Name: Year, dtype: int64

# %%
fao.dropna(subset = ["children_stunted"]) # drop NaN observations childern_stunted
# Out:
#         SSA         Area  Year  gdp_per_capita  drinking_water  \
# 0     False  Afghanistan  2012          2075.5            53.4
# 1     False  Afghanistan  2013          2116.5            56.0
# 2     False  Afghanistan  2014          2102.4            58.7
# 3     False  Afghanistan  2015          2068.3            61.3
# 4     False  Afghanistan  2016          2057.1            64.1
# ...     ...          ...   ...             ...             ...
# 1849   True     Zimbabwe  2016          3678.2            64.5
# 1850   True     Zimbabwe  2017          3795.6            64.0
# 1851   True     Zimbabwe  2018          3923.0            63.5
# 1852   True     Zimbabwe  2019          3630.0            63.1
# 1853   True     Zimbabwe  2020          3353.4            62.7
#
#       sanitation_service  children_stunted  children_overweight  \
# 0                   38.0              44.7                  5.3
# 1                   39.5              43.4                  5.2
# ...

# %%
(
    fao[Year_2012]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2012
# Out:
#         SSA         Area  Year  gdp_per_capita  drinking_water  \
# 981    True   Madagascar  2012     1538.500000            46.2
# 1188   True        Niger  2012     1084.800000            44.3
# 558    True      Eritrea  2012    20344.853769            50.3
# 1647  False  Timor-Leste  2012     3143.300000            68.6
# 261    True      Burundi  2012      862.700000            57.7
#
#       sanitation_service  children_stunted  children_overweight  \
# 981                  9.1              47.9                  1.8
# 1188                11.2              48.3                  0.9
# 558                 11.5              50.1                  1.7
# 1647                48.1              52.8                  3.0
# 261                 45.9              56.8                  2.3
#
#       investment_pct
# 981        22.467511
# 1188       28.154115
# 558        10.549816
# 1647       48.833040
# 261        13.819418

# %%
(
    fao[Year_2013]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2013
# Out:
#         SSA              Area  Year  gdp_per_capita  drinking_water  \
# 1288  False  Papua New Guinea  2013     3512.600000            40.0
# 1189   True             Niger  2013     1098.600000            44.7
# 559    True           Eritrea  2013    20344.853769            50.7
# 1648  False       Timor-Leste  2013     3182.700000            70.8
# 262    True           Burundi  2013      877.300000            58.3
#
#       sanitation_service  children_stunted  children_overweight  \
# 1288                18.8              47.2                  8.2
# 1189                11.7              47.7                  0.9
# 559                 11.6              50.3                  1.7
# 1648                49.2              52.1                  3.0
# 262                 45.9              56.6                  2.4
#
#       investment_pct
# 1288       28.261088
# 1189       30.225499
# 559        10.829225
# 1648       37.301396
# 262        13.524587

# %%
(
    fao[Year_2014]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2014
# Out:
#         SSA              Area  Year  gdp_per_capita  drinking_water  \
# 1289  False  Papua New Guinea  2014     3908.900000            40.7
# 1190   True             Niger  2014     1126.800000            45.1
# 560    True           Eritrea  2014    20344.853769            51.1
# 1649  False       Timor-Leste  2014     3266.700000            73.0
# 263    True           Burundi  2014      886.200000            59.0
#
#       sanitation_service  children_stunted  children_overweight  \
# 1289                18.8              47.3                  8.4
# 1190                12.1              47.4                  1.0
# 560                 11.7              50.3                  1.7
# 1649                50.2              51.5                  2.9
# 263                 45.9              56.4                  2.4
#
#       investment_pct
# 1289       24.890038
# 1190       30.350055
# 560         7.398938
# 1649       37.883403
# 263        13.972976

# %%
(
    fao[Year_2015]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2015
# Out:
#         SSA              Area  Year  gdp_per_capita  drinking_water  \
# 1191   True             Niger  2015     1131.500000            45.5
# 1290  False  Papua New Guinea  2015     4083.300000            41.5
# 561    True           Eritrea  2015    20344.853769            51.5
# 1650  False       Timor-Leste  2015     3295.300000            75.3
# 264    True           Burundi  2015      825.200000            59.6
#
#       sanitation_service  children_stunted  children_overweight  \
# 1191                12.6              47.2                  1.0
# 1290                18.9              47.5                  8.6
# 561                 11.8              50.4                  1.7
# 1650                51.3              50.9                  2.8
# 264                 45.9              56.3                  2.5
#
#       investment_pct
# 1191       32.607014
# 1290        7.532394
# 561        10.283713
# 1650       35.537980
# 264        12.309393

# %%
(
    fao[Year_2016]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2016
# Out:
#         SSA              Area  Year  gdp_per_capita  drinking_water  \
# 1192   True             Niger  2016     1151.200000            45.8
# 1291  False  Papua New Guinea  2016     4222.000000            42.3
# 562    True           Eritrea  2016    20344.853769            51.8
# 1651  False       Timor-Leste  2016     3342.600000            77.5
# 265    True           Burundi  2016      794.600000            60.2
#
#       sanitation_service  children_stunted  children_overweight  \
# 1192                13.0              47.1                  1.2
# 1291                18.9              47.6                  8.7
# 562                 11.9              50.3                  1.8
# 1651                52.4              50.3                  2.8
# 265                 45.9              56.3                  2.6
#
#       investment_pct
# 1192       26.741401
# 1291        7.392577
# 562         7.360791
# 1651       39.648201
# 265        12.542310

# %%
(
    fao[Year_2017]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2017
# Out:
#         SSA              Area  Year  gdp_per_capita  drinking_water  \
# 1193   True             Niger  2017     1163.200000            46.1
# 1292  False  Papua New Guinea  2017     4285.100000            43.0
# 1652  False       Timor-Leste  2017     3177.500000            79.8
# 563    True           Eritrea  2017    20344.853769             NaN
# 266    True           Burundi  2017      773.600000            60.8
#
#       sanitation_service  children_stunted  children_overweight  \
# 1193                13.4              47.0                  1.3
# 1292                19.0              47.9                  8.8
# 1652                53.5              49.9                  2.7
# 563                  NaN              50.2                  1.8
# 266                 45.8              56.5                  2.7
#
#       investment_pct
# 1193       25.428450
# 1292        7.494033
# 1652       34.082943
# 563         8.783084
# 266        12.687871

# %%
(
    fao[Year_2018]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2018
# Out:
#         SSA              Area  Year  gdp_per_capita  drinking_water  \
# 1194   True             Niger  2018     1200.400000            46.4
# 1293  False  Papua New Guinea  2018     4189.600000            43.8
# 1653  False       Timor-Leste  2018     3094.100000            82.1
# 564    True           Eritrea  2018    20344.853769             NaN
# 267    True           Burundi  2018      761.500000            61.5
#
#       sanitation_service  children_stunted  children_overweight  \
# 1194                13.9              46.9                  1.5
# 1293                19.1              48.1                  8.9
# 1653                54.6              49.5                  2.7
# 564                  NaN              49.9                  1.9
# 267                 45.8              56.8                  2.8
#
#       investment_pct
# 1194       27.696816
# 1293        7.636691
# 1653       33.818008
# 564         2.823165
# 267        12.718133

# %%
(
    fao[Year_2019]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2019
# Out:
#         SSA              Area  Year  gdp_per_capita  drinking_water  \
# 1195   True             Niger  2019     1224.400000            46.7
# 1294  False  Papua New Guinea  2019     4292.600000            44.6
# 1654  False       Timor-Leste  2019     3626.700000            83.8
# 565    True           Eritrea  2019    20344.853769             NaN
# 268    True           Burundi  2019      751.400000            62.1
#
#       sanitation_service  children_stunted  children_overweight  \
# 1195                14.3              46.8                  1.6
# 1294                19.1              48.3                  8.9
# 1654                55.7              49.1                  2.7
# 565                  NaN              49.5                  2.0
# 268                 45.7              57.2                  3.0
#
#       investment_pct
# 1195       30.040945
# 1294        7.471472
# 1654       25.243107
# 565         4.017035
# 268        12.090783

# %%
(
    fao[Year_2020]
    .dropna(subset = ["children_stunted"])
    .sort_values(["children_stunted"],
                 ascending=[True])
    .tail(5)
) # worst 5, 2020
# Out:
#         SSA              Area  Year  gdp_per_capita  drinking_water  \
# 1196   True             Niger  2020     1221.300000            46.9
# 1295  False  Papua New Guinea  2020     4063.200000            45.3
# 1655  False       Timor-Leste  2020     3925.900000            85.5
# 566    True           Eritrea  2020    20344.853769             NaN
# 269    True           Burundi  2020      731.100000            62.2
#
#       sanitation_service  children_stunted  children_overweight  \
# 1196                14.8              46.7                  1.9
# 1295                19.2              48.4                  8.9
# 1655                56.8              48.8                  2.6
# 566                  NaN              49.1                  2.1
# 269                 45.7              57.6                  3.1
#
#       investment_pct
# 1196       27.395692
# 1295        8.053913
# 1655       14.892318
# 566         7.290149
# 269        11.246362
