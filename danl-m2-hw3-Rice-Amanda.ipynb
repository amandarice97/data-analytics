# %% [markdown]
# <a href="https://colab.research.google.com/github/amandarice97/data-analytics/blob/main/danl-m2-hw3-Rice-Amanda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load Libraries
# Import the pandas library.
#
# import pandas as pd
#
# Below is nyc_payroll DataFrame that reads the file nyc_payroll.csv containing data of how the New York City’s budget is being spent on salary and overtime pay for all municipal employees (Source: NYC OpenData).
#
# nyc_payroll = pd.read_csv('https://bcdanl.github.io/data/nyc_payroll_2022_2023.csv')

# %%
import pandas as pd
nyc_payroll=pd.read_csv('https://bcdanl.github.io/data/nyc_payroll_2022_2023.csv') #Import dataset
type(nyc_payroll)
nyc_payroll
# Out:
#       Fiscal Year  Payroll Number                     Agency Name Last Name  \
# 0            2022             740   DEPARTMENT OF EDUCATION ADMIN     DAVIS
# 1            2022             746    DEPT OF ED PER DIEM TEACHERS      ZHOU
# 2            2022             747  DEPT OF ED PER SESSION TEACHER     LOPEZ
# 3            2022             742          DEPT OF ED PEDAGOGICAL   KENNEDY
# 4            2022             742          DEPT OF ED PEDAGOGICAL   LICHVAR
# ...           ...             ...                             ...       ...
# 1995         2023             300  BOARD OF ELECTION POLL WORKERS    GARNER
# 1996         2023             742          DEPT OF ED PEDAGOGICAL  FIGUEROA
# 1997         2023             747  DEPT OF ED PER SESSION TEACHER   DIFORTE
# 1998         2023             747  DEPT OF ED PER SESSION TEACHER    BIONDO
# 1999         2023             827        DEPARTMENT OF SANITATION     ARIAS
#
# ...

# %% [markdown]
# #Variable Description
# - Fiscal Year: Fiscal Year;
# - Payroll Number: Payroll Number;
# - Agency Name: The Payroll agency that the employee works for;
# - Last Name: Last name of employee;
# - First Name: First name of employee;
# - Mid Init: Middle initial of employee;
# - Agency Start Date: Date which employee began working for their current agency;
# - Work Location Borough: Borough of employee’s primary work location;
# - Title Description: Civil service title description of the employee;
# - Leave Status as of June 30: Status of employee as of the close of the relevant fiscal year;
# - Base Salary: Base Salary assigned to the employee;
# - Pay Basis: Lists whether the employee is paid on an hourly, per diem or annual basis;
# - Regular Hours: Number of regular hours employee worked in the fiscal year;
# - Regular Gross Paid: The amount paid to the employee for base salary during the fiscal year;
# - OT Hours: Overtime Hours worked by employee in the fiscal year;
# - Total OT Paid: Total overtime pay paid to the employee in the fiscal year;
# - Total Other Pay: Includes any compensation in addition to gross salary and overtime pay, ie Differentials, lump sums, uniform allowance, meal allowance, retroactive pay increases, settlement amounts, and bonus pay, if applicable.

# %% [markdown]
# #Question 1
# Select “First Name”, “Last Name”, “Base Salary”, and “Total OT Paid”, then sort these selected variables by “Base Salary” in descending order and display the top 10 entries.
#
# *Answer*

# %%
nyc_payroll.info() #Number of entries and data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fiscal Year                 2000 non-null   int64
#  1   Payroll Number              2000 non-null   int64
#  2   Agency Name                 2000 non-null   object
#  3   Last Name                   1986 non-null   object
#  4   First Name                  1986 non-null   object
#  5   Mid Init                    1161 non-null   object
#  6   Agency Start Date           2000 non-null   object
#  7   Work Location Borough       2000 non-null   object
#  8   Title Description           2000 non-null   object
#  9   Leave Status as of June 30  2000 non-null   object
#  10  Base Salary                 2000 non-null   float64
#  11  Pay Basis                   2000 non-null   object
#  12  Regular Hours               2000 non-null   float64
# ...

# %%
nyc_payroll.describe(include="all") #Descriptive statistics
# Out:
#         Fiscal Year  Payroll Number             Agency Name  Last Name  \
# count   2000.000000     2000.000000                    2000       1986
# unique          NaN             NaN                      65       1620
# top             NaN             NaN  DEPT OF ED PEDAGOGICAL  RODRIGUEZ
# freq            NaN             NaN                     369         22
# mean    2022.500000      577.804000                     NaN        NaN
# std        0.500125      304.283239                     NaN        NaN
# min     2022.000000        2.000000                     NaN        NaN
# 25%     2022.000000      300.000000                     NaN        NaN
# 50%     2022.500000      742.000000                     NaN        NaN
# 75%     2023.000000      747.000000                     NaN        NaN
# max     2023.000000      996.000000                     NaN        NaN
#
#        First Name Mid Init Agency Start Date Work Location Borough  \
# ...

# %%
(
    nyc_payroll
    .sort_values(["Base Salary", "First Name", "Last Name", "Total OT Paid"],
                 ascending=False)
    .head(10)
) #Sort by descending order, "Base Salary" then "First Name" then "Last Name" then "Total OT Paid"
# Out:
#       Fiscal Year  Payroll Number                   Agency Name  Last Name  \
# 433          2022             858  DEPT OF INFO TECH & TELECOMM    BIMONTE
# 61           2022              69   HRA/DEPT OF SOCIAL SERVICES  BOODANIAN
# 1378         2023             996         NYC HOUSING AUTHORITY     SOHONI
# 1469         2023             996         NYC HOUSING AUTHORITY     KAPLAN
# 73           2022             742        DEPT OF ED PEDAGOGICAL       RICE
# 858          2022              69   HRA/DEPT OF SOCIAL SERVICES   PILEWSKI
# 1379         2023             901   DISTRICT ATTORNEY-MANHATTAN      DAVID
# 425          2022               2           OFFICE OF THE MAYOR    JIMENEZ
# 74           2022             742        DEPT OF ED PEDAGOGICAL       NEDD
# 352          2022             742        DEPT OF ED PEDAGOGICAL     VARGAS
#
#      First Name Mid Init Agency Start Date Work Location Borough  \
# 433     MICHAEL      NaN        06/10/2003              BROOKLYN
# ...

# %% [markdown]
# #Question 2
# Create a new DataFrame that includes employees from the “DEPARTMENT OF EDUCATION ADMIN” agency where the variables are “First Name”, “Last Name”, “Title Description”, “Base Salary”, and “Total OT Paid”. Additionally, include a new variable “Total Compensation” which is the sum of “Base Salary” and “Total OT Paid”.
#
# *Answer*

# %%
nyc_payroll['Total Compensation'] = nyc_payroll['Base Salary'] + nyc_payroll['Total OT Paid'] #Create new variable "Total Compensation"
nyc_payroll
# Out:
#       Fiscal Year  Payroll Number                     Agency Name Last Name  \
# 0            2022             740   DEPARTMENT OF EDUCATION ADMIN     DAVIS
# 1            2022             746    DEPT OF ED PER DIEM TEACHERS      ZHOU
# 2            2022             747  DEPT OF ED PER SESSION TEACHER     LOPEZ
# 3            2022             742          DEPT OF ED PEDAGOGICAL   KENNEDY
# 4            2022             742          DEPT OF ED PEDAGOGICAL   LICHVAR
# ...           ...             ...                             ...       ...
# 1995         2023             300  BOARD OF ELECTION POLL WORKERS    GARNER
# 1996         2023             742          DEPT OF ED PEDAGOGICAL  FIGUEROA
# 1997         2023             747  DEPT OF ED PER SESSION TEACHER   DIFORTE
# 1998         2023             747  DEPT OF ED PER SESSION TEACHER    BIONDO
# 1999         2023             827        DEPARTMENT OF SANITATION     ARIAS
#
# ...

# %%
nyc_payroll_2 = nyc_payroll[['Agency Name', 'First Name', 'Last Name', "Title Description", 'Base Salary', 'Total OT Paid', 'Total Compensation']] #Create new df
nyc_payroll_2
# Out:
#                          Agency Name First Name Last Name  \
# 0      DEPARTMENT OF EDUCATION ADMIN      OSCAR     DAVIS
# 1       DEPT OF ED PER DIEM TEACHERS        JUN      ZHOU
# 2     DEPT OF ED PER SESSION TEACHER    YERIBEL     LOPEZ
# 3             DEPT OF ED PEDAGOGICAL       VERA   KENNEDY
# 4             DEPT OF ED PEDAGOGICAL     AMANDA   LICHVAR
# ...                              ...        ...       ...
# 1995  BOARD OF ELECTION POLL WORKERS   GEOFFREY    GARNER
# 1996          DEPT OF ED PEDAGOGICAL    JESSICA  FIGUEROA
# 1997  DEPT OF ED PER SESSION TEACHER   DANIELLE   DIFORTE
# 1998  DEPT OF ED PER SESSION TEACHER   STEFANIE    BIONDO
# 1999        DEPARTMENT OF SANITATION    ELPIDIO     ARIAS
#
#                                       Title Description  Base Salary  \
# 0     SUBSTANCE ABUSE PREVENTION & INTERVENTION SPEC...     53820.00
# 1                                    TEACHER-GENERAL ED       110.29
# ...

# %%
nyc_payroll_2.set_index("Agency Name", inplace = True) #Create new index

# %%
nyc_payroll_2.loc[ "DEPARTMENT OF EDUCATION ADMIN" ] #Locate "Agency Name" = "DEPARTMENT OF EDUCATION ADMIN"
# Out:
#                               First Name     Last Name  \
# Agency Name
# DEPARTMENT OF EDUCATION ADMIN      OSCAR         DAVIS
# DEPARTMENT OF EDUCATION ADMIN      JENNA    VARNAUSKAS
# DEPARTMENT OF EDUCATION ADMIN  CHRISTINA     GRANQUIST
# DEPARTMENT OF EDUCATION ADMIN     SANDRA         QUIAH
# DEPARTMENT OF EDUCATION ADMIN    SHATARA          EARL
# ...                                  ...           ...
# DEPARTMENT OF EDUCATION ADMIN   DEISMOND          ROSA
# DEPARTMENT OF EDUCATION ADMIN     SERIDE          READ
# DEPARTMENT OF EDUCATION ADMIN      ELISA  CORADO DERAS
# DEPARTMENT OF EDUCATION ADMIN     YAZMYN        YEARDE
# DEPARTMENT OF EDUCATION ADMIN   FOLASADE     AKINTUNDE
#
#                                                                Title Description  \
# Agency Name
# DEPARTMENT OF EDUCATION ADMIN  SUBSTANCE ABUSE PREVENTION & INTERVENTION SPEC...
# DEPARTMENT OF EDUCATION ADMIN                             OCCUPATIONAL THERAPIST
# ...

# %% [markdown]
# #Question 3
# Using set_index(), change the DataFrame’s index to “Last Name”, then locate the data for a specific last name, say “Doe”, and display their “Agency Name”, “Base Salary”, and “Total OT Paid”.
#
# *Answer*

# %%
nyc_payroll.reset_index(inplace = True) #Reset index
nyc_payroll
# Out:
#       level_0  index  Fiscal Year  Payroll Number  \
# 0           0      0         2022             740
# 1           1      1         2022             746
# 2           2      2         2022             747
# 3           3      3         2022             742
# 4           4      4         2022             742
# ...       ...    ...          ...             ...
# 1995     1995   1995         2023             300
# 1996     1996   1996         2023             742
# 1997     1997   1997         2023             747
# 1998     1998   1998         2023             747
# 1999     1999   1999         2023             827
#
#                          Agency Name Last Name First Name Mid Init  \
# 0      DEPARTMENT OF EDUCATION ADMIN     DAVIS      OSCAR      NaN
# 1       DEPT OF ED PER DIEM TEACHERS      ZHOU        JUN      NaN
# 2     DEPT OF ED PER SESSION TEACHER     LOPEZ    YERIBEL        E
# 3             DEPT OF ED PEDAGOGICAL   KENNEDY       VERA        R
# ...

# %%
nyc_payroll.set_index("Last Name", inplace = True) #Create new index

# %%
nyc_payroll.loc[
    ["DAVIS"],
     ["Agency Name", "Base Salary", "Total OT Paid"]
] #Locate "Last Name" = "DAVIS"
# Out:
#                               Agency Name  Base Salary  Total OT Paid
# Last Name
# DAVIS       DEPARTMENT OF EDUCATION ADMIN     53820.00           0.00
# DAVIS               NYC HOUSING AUTHORITY     32950.00        2332.60
# DAVIS         HRA/DEPT OF SOCIAL SERVICES     81452.00        6253.86
# DAVIS             BRONX DISTRICT ATTORNEY    160000.00           0.00
# DAVIS      DEPT OF ED PER SESSION TEACHER        33.18           0.00
# DAVIS         HRA/DEPT OF SOCIAL SERVICES     61178.00           0.00
# DAVIS      DEPT OF ENVIRONMENT PROTECTION     38823.00         225.99

# %% [markdown]
# #Question 4
# Find the 5 employees with the highest “Regular Gross Paid” and calculate their average “OT Hours”. Also, reset the index if you have changed it previously.
#
# *Answer*

# %%
nyc_payroll.reset_index(inplace = True) #Reset index
nyc_payroll
# Out:
#      Last Name  level_0  index  Fiscal Year  Payroll Number  \
# 0        DAVIS        0      0         2022             740
# 1         ZHOU        1      1         2022             746
# 2        LOPEZ        2      2         2022             747
# 3      KENNEDY        3      3         2022             742
# 4      LICHVAR        4      4         2022             742
# ...        ...      ...    ...          ...             ...
# 1995    GARNER     1995   1995         2023             300
# 1996  FIGUEROA     1996   1996         2023             742
# 1997   DIFORTE     1997   1997         2023             747
# 1998    BIONDO     1998   1998         2023             747
# 1999     ARIAS     1999   1999         2023             827
#
#                          Agency Name First Name Mid Init Agency Start Date  \
# 0      DEPARTMENT OF EDUCATION ADMIN      OSCAR      NaN        07/06/2021
# 1       DEPT OF ED PER DIEM TEACHERS        JUN      NaN        07/01/2020
# ...

# %%
nyc_payroll.nlargest(5, 'Regular Gross Paid', keep = "all") #Sort by 5 largest values
# Out:
#       Last Name  level_0  index  Fiscal Year  Payroll Number  \
# 61    BOODANIAN       61     61         2022              69
# 1378     SOHONI     1378   1378         2023             996
# 73         RICE       73     73         2022             742
# 1469     KAPLAN     1469   1469         2023             996
# 1438      NOSSA     1438   1438         2023              56
#
#                       Agency Name First Name Mid Init Agency Start Date  \
# 61    HRA/DEPT OF SOCIAL SERVICES     BEDROS        L        11/05/2007
# 1378        NYC HOUSING AUTHORITY     ARVIND        V        02/11/2019
# 73         DEPT OF ED PEDAGOGICAL   VICTORIA      NaN        09/02/1997
# 1469        NYC HOUSING AUTHORITY     ANDREW        N        12/02/2019
# 1438            POLICE DEPARTMENT     ROBERT        A        07/30/2012
#
#      Work Location Borough             Title Description  \
# 61               MANHATTAN  ADMINISTRATIVE STAFF ANALYST
# ...

# %%
BB = 0.0
AS = 0.0
VR = 0.0
AK = 0.0
RN = 32.5
(BB + AS + VR + AK + RN)/5 #Calucate average "OT Hours"
# Out:
# 6.5

# %% [markdown]
# #Question 5
# Sort the DataFrame by “Fiscal Year” and “Total Other Pay” in descending order, then set “First Name” as the index and use the loc accessor to retrieve the “Total Other Pay” for a specific first name, say “John”.
#
# *Answer*

# %%
nyc_payroll.sort_values(["Fiscal Year", "Total Other Pay"],
                 ascending=False) #Sort in descending order by "Fisal Year" then by "Total Other Pay"
# Out:
#          First Name  Last Name  level_0  index  Fiscal Year  Payroll Number  \
# OT Hours
# 33.98         ANDRE   MCCORKLE     1956   1956         2023              72
# 0.00        STEPHEN    HARTLEY     1966   1966         2023              56
# 0.00         KESHIA     BARLOW     1925   1925         2023             742
# 584.20     NICHOLAS   GISMONDI     1453   1453         2023              57
# 633.40         LACY    HIGGINS     1957   1957         2023              57
# ...             ...        ...      ...    ...          ...             ...
# 186.50       IROPIA     GUPTON      180    180         2022             996
# 0.00           VERA    KENNEDY        3      3         2022             742
# 0.00         SIMONE      HOBBS      200    200         2022              25
# 0.00         LAUREN  FERNANDEZ      356    356         2022             742
# 300.50       MELVIN       RIOS      353    353         2022             996
#
# ...

# %%
nyc_payroll.set_index("First Name", inplace = True) #Create new index

# %%
nyc_payroll.loc[
    ["JOHN"],
     ["Total Other Pay"]
] #Locate "JOHN" and "Total Other Pay"
# Out:
#             Total Other Pay
# First Name
# JOHN               20985.48
# JOHN                   0.00
# JOHN               19878.38
# JOHN               20560.76
# JOHN                   0.00
# JOHN                   1.17
# JOHN               20544.53
# JOHN               14771.53
# JOHN                   0.00
# JOHN                1662.47
# JOHN                3186.05
# JOHN                8790.69
# JOHN               19970.81
# JOHN               22069.38
# JOHN                6558.46
# JOHN               13704.17
# JOHN                4477.75
# JOHN               18133.17
# JOHN               21871.86

# %% [markdown]
# #Question 6
# Select employees who have “OT Hours” greater than 0, calculate their “OT Rate” (Total OT Paid / OT Hours), and then find the employee with the highest “OT Rate”. Display their full name and OT Rate.
#
# *Answer*

# %%
nyc_payroll.reset_index(inplace = True) #Reset index

# %%
nyc_payroll['OT Hours'] > 0 #I'm unsure how to remove values equal to zero in the "OT Hours" Column
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999     True
# Name: OT Hours, Length: 2000, dtype: bool

# %%
nyc_payroll['OT Rate'] = nyc_payroll['Total OT Paid'] / (nyc_payroll['OT Hours'] > 0) #Attempted to divide by "OT Hours" greater than zero

# %%
nyc_payroll.set_index("OT Hours", inplace = True)
nyc_payroll #Set "OT Hours" as the index
# Out:
#          First Name  level_0  index  Fiscal Year  Payroll Number  \
# OT Hours
# 0.0           OSCAR        0      0         2022             740
# 0.0             JUN        1      1         2022             746
# 0.0         YERIBEL        2      2         2022             747
# 0.0            VERA        3      3         2022             742
# 0.0          AMANDA        4      4         2022             742
# ...             ...      ...    ...          ...             ...
# 0.0        GEOFFREY     1995   1995         2023             300
# 0.0         JESSICA     1996   1996         2023             742
# 0.0        DANIELLE     1997   1997         2023             747
# 0.0        STEFANIE     1998   1998         2023             747
# 128.5       ELPIDIO     1999   1999         2023             827
#
#                              Agency Name Mid Init Agency Start Date  \
# OT Hours
# 0.0        DEPARTMENT OF EDUCATION ADMIN      NaN        07/06/2021
# ...

# %%
(
    nyc_payroll
    .sort_index()
    .loc["0.01":]
) #Located all "OT Hours" greater than 0.01
# Out:
#          First Name  level_0  index  Fiscal Year  Payroll Number  \
# OT Hours
# 0.50        KATRINA     1051   1051         2023             740
# 2.00          WENDY      150    150         2022             740
# 2.75      CHRISTINE     1722   1722         2023              67
# 3.00           JUAN     1159   1159         2023              25
# 3.25          MAXIM      834    834         2022             846
# ...             ...      ...    ...          ...             ...
# 1314.12      ROBERT     1294   1294         2023              72
# 1403.00      HUBERT      141    141         2022              72
# 1454.50         NaN     1680   1680         2023             903
# 1646.97        JOHN      221    221         2022              72
# 1875.50    EMMANUEL     1199   1199         2023             996
#
#                              Agency Name Mid Init Agency Start Date  \
# OT Hours
# 0.50       DEPARTMENT OF EDUCATION ADMIN      NaN        07/31/1992
# ...

# %%
nyc_payroll.nlargest(10, 'OT Rate', keep = "all") #Sorted by 10 largest, infinite since I couldn't figure out how to eliminate zero values
# Out:
#              First Name  level_0  index  Fiscal Year  Payroll Number  \
# OT Hours
# 0.0                 NaN      116    116         2022              56
# 0.0                JEAN      166    166         2022             846
# 0.0            JENNIFER      211    211         2022              67
# 0.0                 NaN      297    297         2022             903
# 0.0               JAMES      308    308         2022              57
# 0.0                 NaN      520    520         2022              56
# 0.0               MARLY      548    548         2022             816
# 0.0               DIANA      563    563         2022              69
# 0.0                EARL      587    587         2022              56
# 0.0                 NaN      609    609         2022              56
# 0.0             ANTHONY      730    730         2022              57
# 0.0          BARRINGTON      738    738         2022              57
# ...

# %% [markdown]
# #Question 7
# Sort the DataFrame first by “Work Location Borough” alphabetically, and then by “Total Compensation” (sum of “Base Salary” and “Total OT Paid”) in descending order within each borough.
#
# *Answer*

# %%
nyc_payroll.reset_index(inplace = True) #Reset index

# %%
nyc_payroll['Total Compensation'] = nyc_payroll['Base Salary'] + nyc_payroll['Total OT Paid']

# %%
(
    nyc_payroll
    .sort_values(["Work Location Borough", "Total Compensation"],
                 ascending=[True,False])
    .head(10)
) #Sort in ascending order, "Work Location Borough" then by "Total Compensation" in descending order
# Out:
#       OT Hours First Name  level_0  index  Fiscal Year  Payroll Number  \
# 1172    705.17    DOMINIC     1172   1172         2023              56
# 253       0.00     DONALD      253    253         2022             902
# 1182      0.00    JEFFREY     1182   1182         2023             902
# 602     657.60    ANTHONY      602    602         2022              56
# 307    1039.33       RYAN      307    307         2022              57
# 98     1119.92    MATTHEW       98     98         2022              57
# 1975    763.80       SEAN     1975   1975         2023              57
# 486     375.25    CAROLYN      486    486         2022              56
# 1229      0.00       DAWN     1229   1229         2023               3
# 1564    462.75    OCTAVIA     1564   1564         2023              56
#
#                   Agency Name Mid Init Agency Start Date  \
# 1172        POLICE DEPARTMENT        L        07/02/2001
# 253   BRONX DISTRICT ATTORNEY        C        03/19/2017
# ...
